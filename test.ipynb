# %%
import requests
import json # using .json to reorganize raw data

favorites = {}
fav_artist_list = []

ts_albums = ["Taylor Swift", "Fearless", "Speak Now", "Red", "1989", "Reputation", 
            "Lover", "Folklore", "Evermore", "Midnights"]
fav_albums = {}

# setup ts_albums
for album in ts_albums:
    fav_albums[album] = {"likes": 0}

def initAPI(): 
    """Given input of artist name, returns dictionary of api"""

    url = "https://youtube-music1.p.rapidapi.com/v2/search"
    querystring = {"query":"Taylor Swift"}
    headers = {
	    "X-RapidAPI-Key": "4a1e45ca8dmshcde31ef8a5baed3p1a2a7ejsn9952d2cf96bd", # use personal key
	    "X-RapidAPI-Host": "youtube-music1.p.rapidapi.com"
    }
    response = requests.request("GET", url, headers=headers, params=querystring)

    dict = json.loads(response.text)
    return dict


def album():
    """input artist name, returns list of all artist's albums"""

    api_dictionary = initAPI()
    album_list = [] # create a new list to start from scratch
    songlist = api_dictionary["result"]["songs"] # dictionary values from API dictionary

    for song in songlist:
        if song["album"]["name"] not in album_list: 
            album_list.append(song["album"]["name"])
    return album_list

def song(album):
    """Given input of artist name and album 
    name, returns songs in album if query is
    found, if not, returns Information not found"""

    song_list = []
    api_dictionary = initAPI()
    song_data = api_dictionary["result"]["songs"]

    found = False # by default nothing is found

    for song in song_data:
        if song["album"]["name"] == album: # if machine is able to find song name in dictionary then song names will be printed
            song_list.append(song["name"])
            #print(song["name"])
            found = True # variable is now set as true

    if found == False: 
        print("Information not found")
    return song_list

def fav_artist(artist):
    """Creates dictionary with artist key and number of likes in value"""
    fav_artist_list.append(artist)

    for artist in fav_artist_list:
        favorites[artist] = fav_artist_list.count(artist)
    
    sorted_dict = dict(sorted(favorites.items(), key=lambda x:x[1]))
    res = dict(reversed(list(sorted_dict.items())))

    return res

def add_like(album):
    fav_albums[album]["likes"] = fav_albums[album]["likes"] + 1

# %%
# Example
artist_input = ""
album_input = "1989"

# %%
print(album())
# Out:
# ['Midnights', 'Midnights (3am Edition)', 'reputation', 'This Love (Taylor’s Version)', '1989', "Fearless (Taylor's Version)", 'Speak Now', 'Bad Blood', 'Lover', '1989 (Deluxe Edition)', 'Red', 'Today Was A Fairytale', 'folklore', "Red (Taylor's Version)"]

# %%
print(fav_albums)
# Out:
# {'Taylor Swift': {'likes': 0}, 'Fearless': {'likes': 0}, 'Speak Now': {'likes': 0}, 'Red': {'likes': 0}, '1989': {'likes': 0}, 'Reputation': {'likes': 0}, 'Lover': {'likes': 0}, 'Folklore': {'likes': 0}, 'Evermore': {'likes': 0}, 'Midnights': {'likes': 0}}

# %%
def getAlbum(album):
    return fav_albums[album]

getAlbum("1989")
# Out:
# {'likes': 0}

# %%
initAPI()
# Out:
# {'ok': True,
#  'result': {'songs': [{'id': 'gGwN25z7FrE',
#     'name': 'Taylor Swift - Anti-Hero',
#     'title': 'Anti-Hero',
#     'artists': [{'artist_id': 'UCPC0L1d253x-KuMNwa05TpA',
#       'name': 'Taylor Swift'}],
#     'album': {'album_id': 'MPREb_z0ABWl3jaT0', 'name': 'Midnights'},
#     'duration': 201,
#     'thumbnail': 'https://lh3.googleusercontent.com/omCs21jqwK4Ss_VZxPFKwQP5z0UY0vi_8gXu4XNxHKDgE-GHYHWkIw80XR1uzFgdyhM3PvVUZeZ8iAfF=w120-h120-l90-rj'},
#    {'id': '3YgtjHZyCIQ',
#     'name': 'Taylor Swift - Anti-Hero',
#     'title': 'Anti-Hero',
#     'artists': [{'artist_id': 'UCPC0L1d253x-KuMNwa05TpA',
#       'name': 'Taylor Swift'}],
#     'album': {'album_id': 'MPREb_MOJF3UvLsif',
#      'name': 'Midnights (3am Edition)'},
#     'duration': 201,
#     'thumbnail': 'https://lh3.googleusercontent.com/YT8q7RwmbNVf7EcjSii-T5vm7FZI7_mSb_KYvhfKqvKRWdCTB-mzr2jLZCPwYqER3wHFXhuEQKTKmUCJ=w120-h120-l90-rj'},
#    {'id': 'ywUqTGWU7ec',
#     'name': 'Taylor Swift - Bejeweled',
#     'title': 'Bejeweled',
#     'artists': [{'artist_id': 'UCPC0L1d253x-KuMNwa05TpA',
#       'name': 'Taylor Swift'}],
#     'album': {'album_id': 'MPREb_z0ABWl3jaT0', 'name': 'Midnights'},
#     'duration': 195,
#     'thumbnail': 'https://lh3.googleusercontent.com/omCs21jqwK4Ss_VZxPFKwQP5z0UY0vi_8gXu4XNxHKDgE-GHYHWkIw80XR1uzFgdyhM3PvVUZeZ8iAfF=w120-h120-l90-rj'},
#    {'id': '7SqC7_f_-0M',
#     'name': "Taylor Swift - All Too Well (10 Minute Version) [Taylor's Version] [From The Vault]",
#     'title': "All Too Well (10 Minute Version) [Taylor's Version] [From The Vault]",
#     'artists': [{'artist_id': 'UCPC0L1d253x-KuMNwa05TpA',
#       'name': 'Taylor Swift'}],
#     'album': {'album_id': 'MPREb_A6da7RWlGXJ',
#      'name': "Red (Taylor's Version)"},
#     'duration': 613,
#     'thumbnail': 'https://lh3.googleusercontent.com/d_T3L3Ed5ynZLMVs0Ely4aqTfBZ-y9P9azzlLuKvT2re1QQuxqTxRPoSv082zBOBWmXZZRZKqIFbR7YI=w120-h120-l90-rj'},
#    {'id': 'FhPLQVlUiNQ',
#     'name': 'Taylor Swift - Getaway Car',
#     'title': 'Getaway Car',
#     'artists': [{'artist_id': 'UCPC0L1d253x-KuMNwa05TpA',
#       'name': 'Taylor Swift'}],
#     'album': {'album_id': 'MPREb_BdDqjcHkOwb', 'name': 'reputation'},
#     'duration': 233,
#     'thumbnail': 'https://lh3.googleusercontent.com/RuKPkn6LLmXNOUcyRqh0zQbMWTpZDhHnkxHEZHrv6J8AbxLwemm9F0xaPpHX51WB_Xlj00My9vpZ_zRh=w120-h120-l90-rj'},
#    {'id': 'bhnaPBK9nOQ',
#     'name': "Taylor Swift - Wildest Dreams (Taylor's Version)",
#     'title': "Wildest Dreams (Taylor's Version)",
#     'artists': [{'artist_id': 'UCPC0L1d253x-KuMNwa05TpA',
#       'name': 'Taylor Swift'}],
#     'album': {'album_id': 'MPREb_01wk3vyacN8',
#      'name': 'This Love (Taylor’s Version)'},
#     'duration': 221,
#     'thumbnail': 'https://lh3.googleusercontent.com/84HwoAMSxh8WaUR7iCc4TiXIyfGsbaiiipxDHDl3hnnpialoNXBkv15jtI6VB6smxMOR5Qs0MyW2Ojs=w120-h120-l90-rj'},
#    {'id': '5CbWqM0K2v8',
#     'name': 'Taylor Swift - The Way I Loved You (Taylor’s Version)',
#     'title': 'The Way I Loved You (Taylor’s Version)',
#     'artists': [{'artist_id': 'UCPC0L1d253x-KuMNwa05TpA',
#       'name': 'Taylor Swift'}],
#     'album': {'album_id': 'MPREb_W8Sz9ZLayFV',
#      'name': "Fearless (Taylor's Version)"},
#     'duration': 244,
#     'thumbnail': 'https://lh3.googleusercontent.com/huIYugJjpimikk-tSDJyDU09Jr8vDVJuLOh5uGG6T45c5MEtYvFW_9NlqkHHSaLl231kLBgAS8rtDfQ=w120-h120-l90-rj'},
#    {'id': 'hYt5NSjWKds',
#     'name': 'Taylor Swift - Style',
#     'title': 'Style',
#     'artists': [{'artist_id': 'UCPC0L1d253x-KuMNwa05TpA',
#       'name': 'Taylor Swift'}],
#     'album': {'album_id': 'MPREb_K9GL6DCDUCq', 'name': '1989'},
#     'duration': 230,
#     'thumbnail': 'https://lh3.googleusercontent.com/xlHRih4BZH9CMxxYRc7IYy2ssXT8gvA8ItKoByOGKtUuC0QX7ISvLkTNARz3AlaAaSiu5v-fMJCgw2UU=w120-h120-l90-rj'},
#    {'id': 'KdJHBYb8S4Y',
#     'name': 'Taylor Swift - Better Than Revenge',
#     'title': 'Better Than Revenge',
#     'artists': [{'artist_id': 'UCPC0L1d253x-KuMNwa05TpA',
#       'name': 'Taylor Swift'}],
#     'album': {'album_id': 'MPREb_X9EjrualqFN', 'name': 'Speak Now'},
#     'duration': 217,
#     'thumbnail': 'https://lh3.googleusercontent.com/PNZlZc5kNUgLhpXn5vNkVl8wEsFHg26uEbNMRLRcTioJ8qnAEqV3EOjLwEh7YYeRmNul6TLXEv1v1fk=w120-h120-l90-rj'},
#    {'id': 'Xma9hWNLgZA',
#     'name': 'Taylor Swift - Bad Blood (feat. Kendrick Lamar)',
#     'title': 'Bad Blood (feat. Kendrick Lamar)',
#     'artists': [{'artist_id': 'UCPC0L1d253x-KuMNwa05TpA',
#       'name': 'Taylor Swift'}],
#     'album': {'album_id': 'MPREb_W542RpQS3BU', 'name': 'Bad Blood'},
#     'duration': 200,
#     'thumbnail': 'https://lh3.googleusercontent.com/mnenQ0oxaUZa8gk-zz8iczR2o-ngHtpamSKpg30jhHgPfoGoHfg134aYEPg_ll8by_MTqqFiU7r6Vhkz=w120-h120-l90-rj'},
#    {'id': 'uLL2xTK35Qc',
#     'name': 'Taylor Swift - Lover',
#     'title': 'Lover',
#     'artists': [{'artist_id': 'UCPC0L1d253x-KuMNwa05TpA',
#       'name': 'Taylor Swift'}],
#     'album': {'album_id': 'MPREb_6oiqzmwuS9F', 'name': 'Lover'},
#     'duration': 222,
#     'thumbnail': 'https://lh3.googleusercontent.com/OhxDTHQOQzSrcdgH9hzqzp1v22GYDE-QKnkryvCeq4ddx-3K3_c8oDXN0E6NvHlMn1q4XV59aHr0oL4f=w120-h120-l90-rj'},
#    {'id': 'aPnqx56V8-0',
#     'name': "Taylor Swift - All Too Well (10 Minute Version) [Taylor's Version] [From The Vault]",
#     'title': "All Too Well (10 Minute Version) [Taylor's Version] [From The Vault]",
#     'artists': [{'artist_id': 'UCPC0L1d253x-KuMNwa05TpA',
#       'name': 'Taylor Swift'}],
#     'album': {'album_id': 'MPREb_1fYMhMKHiAU',
#      'name': "Red (Taylor's Version)"},
#     'duration': 613,
#     'thumbnail': 'https://lh3.googleusercontent.com/d_T3L3Ed5ynZLMVs0Ely4aqTfBZ-y9P9azzlLuKvT2re1QQuxqTxRPoSv082zBOBWmXZZRZKqIFbR7YI=w120-h120-l90-rj'},
#    {'id': 'X1ebhLz13Ug',
#     'name': 'Taylor Swift - Last Kiss',
#     'title': 'Last Kiss',
#     'artists': [{'artist_id': 'UCPC0L1d253x-KuMNwa05TpA',
#       'name': 'Taylor Swift'}],
#     'album': {'album_id': 'MPREb_X9EjrualqFN', 'name': 'Speak Now'},
#     'duration': 367,
#     'thumbnail': 'https://lh3.googleusercontent.com/PNZlZc5kNUgLhpXn5vNkVl8wEsFHg26uEbNMRLRcTioJ8qnAEqV3EOjLwEh7YYeRmNul6TLXEv1v1fk=w120-h120-l90-rj'},
#    {'id': 'L0N3C6DsisQ',
#     'name': 'Taylor Swift - Welcome To New York',
#     'title': 'Welcome To New York',
#     'artists': [{'artist_id': 'UCPC0L1d253x-KuMNwa05TpA',
#       'name': 'Taylor Swift'}],
#     'album': {'album_id': 'MPREb_riIJjrsqo2I',
#      'name': '1989 (Deluxe Edition)'},
#     'duration': 212,
#     'thumbnail': 'https://lh3.googleusercontent.com/j8tDC_Ds7M4SqTahuvP4eq5kOVt7waTd7_Qpb7S13h-DCCNBVVdiFgh8aK-Yt8YEJ_dXK2PwTLsL8bqF=w120-h120-l90-rj'},
#    {'id': 'VmBoTeLsKfs',
#     'name': 'Taylor Swift - I Knew You Were Trouble.',
#     'title': 'I Knew You Were Trouble.',
#     'artists': [{'artist_id': 'UCPC0L1d253x-KuMNwa05TpA',
#       'name': 'Taylor Swift'}],
#     'album': {'album_id': 'MPREb_6FbAboRIFSX', 'name': 'Red'},
#     'duration': 220,
#     'thumbnail': 'https://lh3.googleusercontent.com/_HJASc9B_QXn2yoUBn4ZLkn6ka8o_CYX4hNT3HQSeIRcqStiJU15VVtOwlaoFV4KqhJK3d-0W0sw3yQ=w120-h120-l90-rj'},
#    {'id': '6Z3QJ4L1Bg0',
#     'name': "Taylor Swift - This Is Why We Can't Have Nice Things",
#     'title': "This Is Why We Can't Have Nice Things",
#     'artists': [{'artist_id': 'UCPC0L1d253x-KuMNwa05TpA',
#       'name': 'Taylor Swift'}],
#     'album': {'album_id': 'MPREb_BdDqjcHkOwb', 'name': 'reputation'},
#     'duration': 207,
#     'thumbnail': 'https://lh3.googleusercontent.com/RuKPkn6LLmXNOUcyRqh0zQbMWTpZDhHnkxHEZHrv6J8AbxLwemm9F0xaPpHX51WB_Xlj00My9vpZ_zRh=w120-h120-l90-rj'},
#    {'id': 'Gh7u-KTWUq8',
#     'name': 'Taylor Swift - Speak Now',
#     'title': 'Speak Now',
#     'artists': [{'artist_id': 'UCPC0L1d253x-KuMNwa05TpA',
#       'name': 'Taylor Swift'}],
#     'album': {'album_id': 'MPREb_X9EjrualqFN', 'name': 'Speak Now'},
#     'duration': 240,
#     'thumbnail': 'https://lh3.googleusercontent.com/PNZlZc5kNUgLhpXn5vNkVl8wEsFHg26uEbNMRLRcTioJ8qnAEqV3EOjLwEh7YYeRmNul6TLXEv1v1fk=w120-h120-l90-rj'},
#    {'id': 'FNEoPctNIUE',
#     'name': 'Taylor Swift - Dress',
#     'title': 'Dress',
#     'artists': [{'artist_id': 'UCPC0L1d253x-KuMNwa05TpA',
#       'name': 'Taylor Swift'}],
#     'album': {'album_id': 'MPREb_BdDqjcHkOwb', 'name': 'reputation'},
#     'duration': 230,
#     'thumbnail': 'https://lh3.googleusercontent.com/RuKPkn6LLmXNOUcyRqh0zQbMWTpZDhHnkxHEZHrv6J8AbxLwemm9F0xaPpHX51WB_Xlj00My9vpZ_zRh=w120-h120-l90-rj'},
#    {'id': 'rLiXLzd2Ol8',
#     'name': 'Taylor Swift - Today Was A Fairytale',
#     'title': 'Today Was A Fairytale',
#     'artists': [{'artist_id': 'UCPC0L1d253x-KuMNwa05TpA',
#       'name': 'Taylor Swift'}],
#     'album': {'album_id': 'MPREb_aojtNssjCLw',
#      'name': 'Today Was A Fairytale'},
#     'duration': 243,
#     'thumbnail': 'https://lh3.googleusercontent.com/pOuse_olXR6pb0aWPu1UM8apo7yaqA82KCMwaVsTkKvaj2gXIbc7Lx4u2QflBgf6yqEYFzGjwfFDwYI=w120-h120-l90-rj'},
#    {'id': 'R6wHAaa7e2U',
#     'name': 'Taylor Swift - Never Grow Up',
#     'title': 'Never Grow Up',
#     'artists': [{'artist_id': 'UCPC0L1d253x-KuMNwa05TpA',
#       'name': 'Taylor Swift'}],
#     'album': {'album_id': 'MPREb_X9EjrualqFN', 'name': 'Speak Now'},
#     'duration': 290,
#     'thumbnail': 'https://lh3.googleusercontent.com/PNZlZc5kNUgLhpXn5vNkVl8wEsFHg26uEbNMRLRcTioJ8qnAEqV3EOjLwEh7YYeRmNul6TLXEv1v1fk=w120-h120-l90-rj'}],
#   'videos': [{'id': 'b1kbLwvqugk', 'title': 'Anti-Hero', 'duration': 310},
#    {'id': 'b7QlX3yR2xs', 'title': 'Bejeweled', 'duration': 354},
#    {'id': '3tmd-ClpJxA', 'title': 'Look What You Made Me Do', 'duration': 256},
#    {'id': 'cMPEd8m79Hw', 'title': 'Begin Again', 'duration': 251},
#    {'id': '9eakEQSBR8o',
#     'title': 'Taylor Swift - I Knew You Were Trouble (Lyrics)',
#     'duration': 224},
#    {'id': 'dfnCAmr569k',
#     'title': 'End Game (feat. Ed Sheeran & Future)',
#     'duration': 252},
#    {'id': 'xKCek6_dB0M', 'title': 'Teardrops On My Guitar', 'duration': 218},
#    {'id': 'jYa1eI1hpDE', 'title': 'Mean', 'duration': 244},
#    {'id': 'Dkk9gvTmCXY', 'title': 'You Need To Calm Down', 'duration': 211},
#    {'id': 'tRFLs_-54gE',
#     'title': 'Taylor Swift - Love Story (Lyrics) romeo save me',
#     'duration': 235},
#    {'id': '8xG7mH8i-WE',
#     'title': 'Shake It Off - Taylor Swift (Lyrics) 🎵',
#     'duration': 218},
#    {'id': 'Pb-K2tXWK4w', 'title': 'Fifteen', 'duration': 304},
#    {'id': '_k7hmkf2dvQ',
#     'title': 'Taylor Swift - Look What You Made Me Do (Lyrics)',
#     'duration': 213},
#    {'id': 'UYIYdwe4I50',
#     'title': 'Bon Iver w/ Taylor Swift - Exile - London 10/26/22',
#     'duration': 328},
#    {'id': 'iFX6_9h7th0',
#     'title': 'The Great War (Official Lyric Video)',
#     'duration': 244},
#    {'id': '5UMCrq-bBCg',
#     'title': 'Taylor Swift ft. Chris Stapleton - I Bet You Think About Me (...',
#     'duration': 376},
#    {'id': 'fvptTUPONpM',
#     'title': 'Taylor Swift - Look What You Made Me Do PARODY - TEEN CRUSH',
#     'duration': 217},
#    {'id': 'yCMqcFAigRg', 'title': 'Picture to Burn', 'duration': 212}]}}

# %%
album_list = ['Midnights', 'Midnights (3am Edition)', 'reputation', 'This Love (Taylorâ€™s Version)', "Fearless (Taylor's Version)", '1989', 'Bad Blood', 'Speak Now', 'Lover', "Red (Taylor's Version)", '1989 (Deluxe Edition)', 'Red', 'Today Was A Fairytale']
as_dict = {}
def add_element(dict, key, value):
    if key not in dict:
        dict[key] = []
    dict[key].append(value)
    
def album_song():
    for i in range(len(album_list)):
        album_var = album_list[i]
        # print(album_var)
        song1 = song(album_var)
        #songs = song(album_var)
        #as_dict[album_var].append(songs)
        add_element(as_dict, album_var, song1)
    return as_dict

print(album_song())
# Out:
# Information not found
# {'Midnights': [['Taylor Swift - Anti-Hero', 'Taylor Swift - Bejeweled']], 'Midnights (3am Edition)': [['Taylor Swift - Anti-Hero', 'Taylor Swift - Maroon']], 'reputation': [['Taylor Swift - Getaway Car', "Taylor Swift - This Is Why We Can't Have Nice Things", 'Taylor Swift - Dress']], 'This Love (Taylorâ€™s Version)': [[]], "Fearless (Taylor's Version)": [['Taylor Swift - The Way I Loved You (Taylor’s Version)']], '1989': [['Taylor Swift - Style']], 'Bad Blood': [['Taylor Swift - Bad Blood (feat. Kendrick Lamar)']], 'Speak Now': [['Taylor Swift - Better Than Revenge', 'Taylor Swift - Last Kiss', 'Taylor Swift - Speak Now', 'Taylor Swift - Never Grow Up']], 'Lover': [['Taylor Swift - Lover']], "Red (Taylor's Version)": [["Taylor Swift - All Too Well (Taylor's Version)"]], '1989 (Deluxe Edition)': [['Taylor Swift - Welcome To New York']], 'Red': [['Taylor Swift - I Knew You Were Trouble.']], 'Today Was A Fairytale': [['Taylor Swift - Today Was A Fairytale']]}

# %%
def song(album):
    """Given input of artist name and album 
    name, returns songs in album if query is
    found, if not, returns Information not found"""

    song_list = []
    api_dictionary = initAPI()
    print(api_dictionary)
    song_data = api_dictionary["result"]["songs"]

    found = False # by default nothing is found

    for song in song_data:
        if song["album"]["name"] == album: # if machine is able to find song name in dictionary then song names will be printed
            song_list.append(song["name"])
            #print(song["name"])
            found = True # variable is now set as true
    return song_list
    
song("Midnights")
# Out:
# {'ok': True, 'result': {'songs': [{'id': 'gGwN25z7FrE', 'name': 'Taylor Swift - Anti-Hero', 'title': 'Anti-Hero', 'artists': [{'artist_id': 'UCPC0L1d253x-KuMNwa05TpA', 'name': 'Taylor Swift'}], 'album': {'album_id': 'MPREb_z0ABWl3jaT0', 'name': 'Midnights'}, 'duration': 201, 'thumbnail': 'https://lh3.googleusercontent.com/omCs21jqwK4Ss_VZxPFKwQP5z0UY0vi_8gXu4XNxHKDgE-GHYHWkIw80XR1uzFgdyhM3PvVUZeZ8iAfF=w120-h120-l90-rj'}, {'id': '3YgtjHZyCIQ', 'name': 'Taylor Swift - Anti-Hero', 'title': 'Anti-Hero', 'artists': [{'artist_id': 'UCPC0L1d253x-KuMNwa05TpA', 'name': 'Taylor Swift'}], 'album': {'album_id': 'MPREb_MOJF3UvLsif', 'name': 'Midnights (3am Edition)'}, 'duration': 201, 'thumbnail': 'https://lh3.googleusercontent.com/YT8q7RwmbNVf7EcjSii-T5vm7FZI7_mSb_KYvhfKqvKRWdCTB-mzr2jLZCPwYqER3wHFXhuEQKTKmUCJ=w120-h120-l90-rj'}, {'id': 'xYLxUJ9v6KU', 'name': 'Taylor Swift - I Did Something Bad', 'title': 'I Did Something Bad', 'artists': [{'artist_id': 'UCPC0L1d253x-KuMNwa05TpA', 'name': 'Taylor Swift'}], 'album': {'album_id': 'MPREb_BdDqjcHkOwb', 'name': 'reputation'}, 'duration': 238, 'thumbnail': 'https://lh3.googleusercontent.com/RuKPkn6LLmXNOUcyRqh0zQbMWTpZDhHnkxHEZHrv6J8AbxLwemm9F0xaPpHX51WB_Xlj00My9vpZ_zRh=w120-h120-l90-rj'}, {'id': 'FhPLQVlUiNQ', 'name': 'Taylor Swift - Getaway Car', 'title': 'Getaway Car', 'artists': [{'artist_id': 'UCPC0L1d253x-KuMNwa05TpA', 'name': 'Taylor Swift'}], 'album': {'album_id': 'MPREb_BdDqjcHkOwb', 'name': 'reputation'}, 'duration': 233, 'thumbnail': 'https://lh3.googleusercontent.com/RuKPkn6LLmXNOUcyRqh0zQbMWTpZDhHnkxHEZHrv6J8AbxLwemm9F0xaPpHX51WB_Xlj00My9vpZ_zRh=w120-h120-l90-rj'}, {'id': 'bhnaPBK9nOQ', 'name': "Taylor Swift - Wildest Dreams (Taylor's Version)", 'title': "Wildest Dreams (Taylor's Version)", 'artists': [{'artist_id': 'UCPC0L1d253x-KuMNwa05TpA', 'name': 'Taylor Swift'}], 'album': {'album_id': 'MPREb_01wk3vyacN8', 'name': 'This Love (Taylor’s Version)'}, 'duration': 221, 'thumbnail': 'https://lh3.googleusercontent.com/84HwoAMSxh8WaUR7iCc4TiXIyfGsbaiiipxDHDl3hnnpialoNXBkv15jtI6VB6smxMOR5Qs0MyW2Ojs=w120-h120-l90-rj'}, {'id': 'hYt5NSjWKds', 'name': 'Taylor Swift - Style', 'title': 'Style', 'artists': [{'artist_id': 'UCPC0L1d253x-KuMNwa05TpA', 'name': 'Taylor Swift'}], 'album': {'album_id': 'MPREb_K9GL6DCDUCq', 'name': '1989'}, 'duration': 230, 'thumbnail': 'https://lh3.googleusercontent.com/xlHRih4BZH9CMxxYRc7IYy2ssXT8gvA8ItKoByOGKtUuC0QX7ISvLkTNARz3AlaAaSiu5v-fMJCgw2UU=w120-h120-l90-rj'}, {'id': '5CbWqM0K2v8', 'name': 'Taylor Swift - The Way I Loved You (Taylor’s Version)', 'title': 'The Way I Loved You (Taylor’s Version)', 'artists': [{'artist_id': 'UCPC0L1d253x-KuMNwa05TpA', 'name': 'Taylor Swift'}], 'album': {'album_id': 'MPREb_W8Sz9ZLayFV', 'name': "Fearless (Taylor's Version)"}, 'duration': 244, 'thumbnail': 'https://lh3.googleusercontent.com/huIYugJjpimikk-tSDJyDU09Jr8vDVJuLOh5uGG6T45c5MEtYvFW_9NlqkHHSaLl231kLBgAS8rtDfQ=w120-h120-l90-rj'}, {'id': 'KdJHBYb8S4Y', 'name': 'Taylor Swift - Better Than Revenge', 'title': 'Better Than Revenge', 'artists': [{'artist_id': 'UCPC0L1d253x-KuMNwa05TpA', 'name': 'Taylor Swift'}], 'album': {'album_id': 'MPREb_X9EjrualqFN', 'name': 'Speak Now'}, 'duration': 217, 'thumbnail': 'https://lh3.googleusercontent.com/PNZlZc5kNUgLhpXn5vNkVl8wEsFHg26uEbNMRLRcTioJ8qnAEqV3EOjLwEh7YYeRmNul6TLXEv1v1fk=w120-h120-l90-rj'}, {'id': 'uLL2xTK35Qc', 'name': 'Taylor Swift - Lover', 'title': 'Lover', 'artists': [{'artist_id': 'UCPC0L1d253x-KuMNwa05TpA', 'name': 'Taylor Swift'}], 'album': {'album_id': 'MPREb_6oiqzmwuS9F', 'name': 'Lover'}, 'duration': 222, 'thumbnail': 'https://lh3.googleusercontent.com/OhxDTHQOQzSrcdgH9hzqzp1v22GYDE-QKnkryvCeq4ddx-3K3_c8oDXN0E6NvHlMn1q4XV59aHr0oL4f=w120-h120-l90-rj'}, {'id': 'X1ebhLz13Ug', 'name': 'Taylor Swift - Last Kiss', 'title': 'Last Kiss', 'artists': [{'artist_id': 'UCPC0L1d253x-KuMNwa05TpA', 'name': 'Taylor Swift'}], 'album': {'album_id': 'MPREb_X9EjrualqFN', 'name': 'Speak Now'}, 'duration': 367, 'thumbnail': 'https://lh3.goog ...
# ['Taylor Swift - Anti-Hero', 'Taylor Swift - Bejeweled']
