# %%
import requests
import json # using .json to reorganize raw data

favorites = {}
fav_artist_list = []

def extract_api_data(artist): 
    """Given input of artist name, returns dictionary of api"""

    url = "https://youtube-music1.p.rapidapi.com/v2/search"
    querystring = {"query":artist}
    headers = {
	    "X-RapidAPI-Key": "4a1e45ca8dmshcde31ef8a5baed3p1a2a7ejsn9952d2cf96bd", # use personal key
	    "X-RapidAPI-Host": "youtube-music1.p.rapidapi.com"
    }
    response = requests.request("GET", url, headers=headers, params=querystring)

    dict = json.loads(response.text)
    return dict

def album(artist):
    """input artist name, returns list of all artist's albums"""

    api_dictionary = extract_api_data(artist)
    album_list = [] # create a new list to start from scratch
    songlist = api_dictionary["result"]["songs"] # dictionary values from API dictionary

    for song in songlist:
        if song["album"]["name"] not in album_list: 
            album_list.append(song["album"]["name"])
    return album_list


def song(artist, album):
    """Given input of artist name and album 
    name, returns songs in album if query is
    found, if not, returns Information not found"""

    song_list = []
    api_dictionary = extract_api_data(artist)
    song_data = api_dictionary["result"]["songs"]

    found = False # by default nothing is found

    for song in song_data:
        if song["album"]["name"] == album: # if machine is able to find song name in dictionary then song names will be printed
            song_list.append(song["name"])
            #print(song["name"])
            found = True # variable is now set as true

    if found == False: 
        print("Information not found")
    return song_list

def fav_artist(artist):
    """Creates dictionary with artist key and number of likes in value"""
    fav_artist_list.append(artist)

    for artist in fav_artist_list:
        favorites[artist] = fav_artist_list.count(artist)
    
    return favorites

# %%
# Example
artist_input = "Taylor Swift"
album_input = "1989"

# %%
print(album(artist_input))
# Out:
# ['Midnights (3am Edition)', 'Midnights', "Red (Taylor's Version)", 'This Love (Taylor’s Version)', '1989', 'reputation', 'Lover', "Fearless (Taylor's Version)", 'Speak Now', 'Hannah Montana The Movie']

# %%
print(song(artist_input, album_input))
# Out:
# ['Taylor Swift - Style', 'Taylor Swift - Blank Space']

# %%
input_artist = "Taylor Swift"
fav_artist(input_artist)
# Out:
# {'Taylor Swift': 1}

# %%
artist = "Taylor Swift" # allow user to input the artist they want

url = "https://youtube-music1.p.rapidapi.com/v2/search"

querystring = {"query":artist}

headers = {
    "X-RapidAPI-Key": "4a1e45ca8dmshcde31ef8a5baed3p1a2a7ejsn9952d2cf96bd", # use personal key
    "X-RapidAPI-Host": "youtube-music1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)
string_val = response.text
dict_val = json.loads(string_val)

formated = json.dumps(dict_val, indent=4)
print(formated)
# Out:
# {
#     "ok": true,
#     "result": {
#         "songs": [
#             {
#                 "id": "3YgtjHZyCIQ",
#                 "name": "Taylor Swift - Anti-Hero",
#                 "title": "Anti-Hero",
#                 "artists": [
#                     {
#                         "artist_id": "UCPC0L1d253x-KuMNwa05TpA",
#                         "name": "Taylor Swift"
#                     }
#                 ],
#                 "album": {
#                     "album_id": "MPREb_MOJF3UvLsif",
#                     "name": "Midnights (3am Edition)"
#                 },
#                 "duration": 201,
#                 "thumbnail": "https://lh3.googleusercontent.com/YT8q7RwmbNVf7EcjSii-T5vm7FZI7_mSb_KYvhfKqvKRWdCTB-mzr2jLZCPwYqER3wHFXhuEQKTKmUCJ=w120-h120-l90-rj"
#             },
#             {
#                 "id": "ywUqTGWU7ec",
#                 "name": "Taylor Swift - Bejeweled",
#                 "title": "Bejeweled",
#                 "artists": [
#                     {
#                         "artist_id": "UCPC0L1d253x-KuMNwa05TpA",
#                         "name": "Taylor Swift"
#                     }
#                 ],
#                 "album": {
#                     "album_id": "MPREb_z0ABWl3jaT0",
#                     "name": "Midnights"
#                 },
#                 "duration": 195,
#                 "thumbnail": "https://lh3.googleusercontent.com/omCs21jqwK4Ss_VZxPFKwQP5z0UY0vi_8gXu4XNxHKDgE-GHYHWkIw80XR1uzFgdyhM3PvVUZeZ8iAfF=w120-h120-l90-rj"
#             },
#             {
#                 "id": "aPnqx56V8-0",
#                 "name": "Taylor Swift - All Too Well (10 Minute Version) [Taylor's Version] [From The Vault]",
#                 "title": "All Too Well (10 Minute Version) [Taylor's Version] [From The Vault]",
#                 "artists": [
#                     {
#                         "artist_id": "UCPC0L1d253x-KuMNwa05TpA",
#                         "name": "Taylor Swift"
#                     }
#                 ],
#                 "album": {
#                     "album_id": "MPREb_1fYMhMKHiAU",
#                     "name": "Red (Taylor's Version)"
#                 },
#                 "duration": 613,
#                 "thumbnail": "https://lh3.googleusercontent.com/d_T3L3Ed5ynZLMVs0Ely4aqTfBZ-y9P9azzlLuKvT2re1QQuxqTxRPoSv082zBOBWmXZZRZKqIFbR7YI=w120-h120-l90-rj"
#             },
#             {
#                 "id": "gGwN25z7FrE",
#                 "name": "Taylor Swift - Anti-Hero",
#                 "title": "Anti-Hero",
#                 "artists": [
#                     {
#                         "artist_id": "UCPC0L1d253x-KuMNwa05TpA",
#                         "name": "Taylor Swift"
#                     }
#                 ],
#                 "album": {
#                     "album_id": "MPREb_z0ABWl3jaT0",
#                     "name": "Midnights"
#                 },
#                 "duration": 201,
#                 "thumbnail": "https://lh3.googleusercontent.com/omCs21jqwK4Ss_VZxPFKwQP5z0UY0vi_8gXu4XNxHKDgE-GHYHWkIw80XR1uzFgdyhM3PvVUZeZ8iAfF=w120-h120-l90-rj"
#             },
#             {
#                 "id": "6hCqRb8Dtvo",
#                 "name": "Taylor Swift - Blank Space",
#                 "title": "Blank Space",
#                 "artists": [
#                     {
#                         "artist_id": "UCPC0L1d253x-KuMNwa05TpA",
#                         "name": "Taylor Swift"
#                     }
#                 ],
#                 "album": {
#                     "album_id": "MPREb_K9GL6DCDUCq",
#                     "name": "1989"
#                 },
#                 "duration": 231,
#                 "thumbnail": "https://lh3.googleusercontent.com/xlHRih4BZH9CMxxYRc7IYy2ssXT8gvA8ItKoByOGKtUuC0QX7ISvLkTNARz3AlaAaSiu5v-fMJCgw2UU=w120-h120-l90-rj"
#             },
#             {
#                 "id": "bhnaPBK9nOQ",
#                 "name": "Taylor Swift - Wildest Dreams (Taylor's Version)",
#                 "title": "Wildest Dreams (Taylor's Version)",
#                 "artists": [
#                     {
#                         "artist_id": "UCPC0L1d253x-KuMNwa05TpA",
#                         "name": "Taylor Swift"
#                     }
#                 ],
#                 "album": {
#                     "album_id": "MPREb_01wk3vyacN8",
#                     "name": "This Love (Taylor\u2019s Version)"
#                 },
#                 "duration": 221,
#                 "thumbnail": "https://lh3.googleusercontent.com/84HwoAMSxh8WaUR7iCc4TiXIyfGsbaiiipxDHDl3hnnpialoNXBkv15jtI6VB6smxMOR5Qs0MyW2Ojs=w120-h120-l90-rj"
#             },
#             {
#                 "id": "7SqC7_f_-0M",
#                 "name": "Taylor Swift - All Too Well (10 Minute Version) [Taylor's Version] [From The Vault]",
#                 "title": "All Too Well (10 Minute Version) [Taylor's Version] [From The Vault]",
#                 "artists": [
#                     {
#                         "artist_id": "UCPC0L1d253x-KuMNwa05TpA",
#                         "name": "Taylor Swift"
#                     }
#                 ],
#                 "album": {
#                     "album_id": "MPREb_A6da7RWlGXJ",
#                     "name": "Red (Taylor's Version)"
#                 },
#                 "duration": 613,
#                 "thumbnail": "https://lh3.googleusercontent.com/d_T3L3Ed5ynZLMVs0Ely4aqTfBZ-y9P9azzlLuKvT2re1QQuxqTxRPoSv082zBOBWmXZZRZKqIFbR7YI=w120-h120-l90-rj"
#             },
#             {
#                 "id": "hYt5NSjWKds",
#                 "name": "Taylor Swift - Style",
#                 "title": "Style",
#                 "artists": [
#                     {
#                         "artist_id": "UCPC0L1d253x-KuMNwa05TpA",
#                         "name": "Taylor Swift"
#                     }
#                 ],
#                 "album": {
#                     "album_id": "MPREb_K9GL6DCDUCq",
#                     "name": "1989"
#                 },
#                 "duration": 230,
#                 "thumbnail": "https://lh3.googleusercontent.com/xlHRih4BZH9CMxxYRc7IYy2ssXT8gvA8ItKoByOGKtUuC0QX7ISvLkTNARz3AlaAaSiu5v-fMJCgw2UU=w120-h120-l90-rj"
#             },
#             {
#                 "id": "FhPLQVlUiNQ",
#                 "name": "Taylor Swift - Getaway Car",
#                 "title": "Getaway Car",
#                 "artists": [
#                     {
#                         "artist_id": "UCPC0L1d253x-KuMNwa05TpA",
#                         "name": "Taylor Swift"
#                     }
#                 ],
#                 "album": {
#                     "album_id": "MPREb_BdDqjcHkOwb",
#                     "name": "reputation"
#                 },
#                 "duration": 233,
#                 "thumbnail": "https://lh3.googleusercontent.com/RuKPkn6LLmXNOUcyRqh0zQbMWTpZDhHnkxHEZHrv6J8AbxLwemm9F0xaPpHX51WB_Xlj00My9vpZ_zRh=w120-h120-l90-rj"
#             },
#             {
#                 "id": "FNEoPctNIUE",
#                 "name": "Taylor Swift - Dress",
#                 "title": "Dress",
#                 "artists": [
#                     {
#                         "artist_id": "UCPC0L1d253x-KuMNwa05TpA",
#                         "name": "Taylor Swift"
#                     }
#                 ],
#                 "album": {
#                     "album_id": "MPREb_BdDqjcHkOwb",
#                     "name": "reputation"
#                 },
#                 "duration": 230,
#                 "thumbnail": "https://lh3.googleusercontent.com/RuKPkn6LLmXNOUcyRqh0zQbMWTpZDhHnkxHEZHrv6J8AbxLwemm9F0xaPpHX51WB_Xlj00My9vpZ_zRh=w120-h120-l90-rj"
#             },
#             {
#                 "id": "Gh7u-KTWUq8",
#                 "name": "Taylor Swift - Speak Now",
#                 "title": "Speak Now",
#                 "artists": [
#                     {
#                         "artist_id": "UCPC0L1d253x-KuMNwa05TpA",
#                         "name": "Taylor Swift"
#                     }
#                 ],
#                 "album": {
#                     "album_id": "MPREb_X9EjrualqFN",
#                     "name": "Speak Now"
#                 },
#                 "duration": 240,
#                 "thumbnail": "https://lh3.googleusercontent.com/PNZlZc5kNUgLhpXn5vNkVl8wEsFHg26uEbNMRLRcTioJ8qnAEqV3EOjLwEh7YYeRmNul6TLXEv1v1fk=w120-h120-l90-rj"
#             },
#             {
#                 "id": "5CbWqM0K2v8",
#                 "name": "Taylor Swift - The Way I Loved You (Taylor\u2019s Version)",
#                 "title": "The Way I Loved You (Taylor\u2019s Version)",
#                 "artists": [
#                     {
#                         "artist_id": "UCPC0L1d253x-KuMNwa05TpA",
#                         "name": "Taylor Swift"
#                     }
#                 ],
#                 "album": {
#                     "album_id": "MPREb_W8Sz9ZLayFV",
#                     "name": "Fearless (Taylor's Version)"
#                 },
#                 "duration": 244,
#                 "thumbnail": "https://lh3.googleusercontent.com/huIYugJjpimikk-tSDJyDU09Jr8vDVJuLOh5uGG6T45c5MEtYvFW_9NlqkHHSaLl231kLBgAS8rtDfQ=w120-h120-l90-rj"
#             },
#             {
#                 "id": "X1ebhLz13Ug",
#                 "name": "Taylor Swift - Last Kiss",
#                 "title": "Last Kiss",
#                 "artists": [
#                     {
#                         "artist_id": "UCPC0L1d253x-KuMNwa05TpA",
#                         "name": "Taylor Swift"
#                     }
#                 ],
#                 "album": {
#                     "album_id": "MPREb_X9EjrualqFN",
#                     "name": "Speak Now"
#                 },
#                 "duration": 367,
#                 "thumbnail": "https://lh3.googleusercontent.com/PNZlZc5kNUgLhpXn5vNkVl8wEsFHg26uEbNMRLRcTioJ8qnAEqV3EOjLwEh7YYeRmNul6TLXEv1v1fk=w120-h120-l90-rj"
#             },
#             {
#                 "id": "wKoHR305w_c",
#                 "name": "Taylor Swift - You Belong With Me",
#                 "title": "You Belong With Me",
#                 "artists": [
#                     {
#                         "artist_id": "UCPC0L1d253x-KuMNwa05TpA",
#                         "name": "Taylor Swift"
#                     }
#                 ],
#                 "album": {
#                     "album_id": "MPREb_WOymlv5h6Sg",
#                     "name": "Fearless"
#                 },
#                 "duration": 231,
#                 "thumbnail": "https://lh3.googleusercontent.com/I1yuekDjG00Y2Wha1V9i1vyD0r4wsLU-CytJlCznEKFgByyR0mvoJ8gt-ldnui4SGc0l0ZMN2APnRRw=w120-h120-l90-rj"
#             },
#             {
#                 "id": "fvg01l43XBc",
#                 "name": "Taylor Swift - Enchanted",
#                 "title": "Enchanted",
#                 "artists": [
#                     {
#                         "artist_id": "UCPC0L1d253x-KuMNwa05TpA",
#                         "name": "Taylor Swift"
#                     }
#                 ],
#                 "album": {
#                     "album_id": "MPREb_X9EjrualqFN",
#                     "name": "Speak Now"
#                 },
#                 "duration": 352,
#                 "thumbnail": "https://lh3.googleusercontent.com/PNZlZc5kNUgLhpXn5vNkVl8wEsFHg26uEbNMRLRcTioJ8qnAEqV3EOjLwEh7YYeRmNul6TLXEv1v1fk=w120-h120-l90-rj"
#             },
#             {
#                 "id": "KdJHBYb8S4Y",
#                 "name": "Taylor Swift - Better Than Revenge",
#                 "title": "Better Than Revenge",
#                 "artists": [
#                     {
#                         "artist_id": "UCPC0L1d253x-KuMNwa05TpA",
#                         "name": "Taylor Swift"
#                     }
#                 ],
#                 "album": {
#                     "album_id": "MPREb_X9EjrualqFN",
#                     "name": "Speak Now"
#                 },
#                 "duration": 217,
#                 "thumbnail": "https://lh3.googleusercontent.com/PNZlZc5kNUgLhpXn5vNkVl8wEsFHg26uEbNMRLRcTioJ8qnAEqV3EOjLwEh7YYeRmNul6TLXEv1v1fk=w120-h120-l90-rj"
#             },
#             {
#                 "id": "5U7bF68xcRg",
#                 "name": "Taylor Swift - King Of My Heart",
#                 "title": "King Of My Heart",
#                 "artists": [
#                     {
#                         "artist_id": "UCPC0L1d253x-KuMNwa05TpA",
#                         "name": "Taylor Swift"
#                     }
#                 ],
#                 "album": {
#                     "album_id": "MPREb_BdDqjcHkOwb",
#                     "name": "reputation"
#                 },
#                 "duration": 214,
#                 "thumbnail": "https://lh3.googleusercontent.com/RuKPkn6LLmXNOUcyRqh0zQbMWTpZDhHnkxHEZHrv6J8AbxLwemm9F0xaPpHX51WB_Xlj00My9vpZ_zRh=w120-h120-l90-rj"
#             },
#             {
#                 "id": "PCiVzWLxDSk",
#                 "name": "Taylor Swift - Labyrinth",
#                 "title": "Labyrinth",
#                 "artists": [
#                     {
#                         "artist_id": "UCPC0L1d253x-KuMNwa05TpA",
#                         "name": "Taylor Swift"
#                     }
#                 ],
#                 "album": {
#                     "album_id": "MPREb_z0ABWl3jaT0",
#                     "name": "Midnights"
#                 },
#                 "duration": 248,
#                 "thumbnail": "https://lh3.googleusercontent.com/omCs21jqwK4Ss_VZxPFKwQP5z0UY0vi_8gXu4XNxHKDgE-GHYHWkIw80XR1uzFgdyhM3PvVUZeZ8iAfF=w120-h120-l90-rj"
#             },
#             {
#                 "id": "VOk5_r3Fm0g",
#                 "name": "Taylor Swift - Crazier",
#                 "title": "Crazier",
#                 "artists": [
#                     {
#                         "artist_id": "UCPC0L1d253x-KuMNwa05TpA",
#                         "name": "Taylor Swift"
#                     }
#                 ],
#                 "album": {
#                     "album_id": "MPREb_Z43YxzbRqSl",
#                     "name": "Hannah Montana The Movie"
#                 },
#                 "duration": 191,
#                 "thumbnail": "https://lh3.googleusercontent.com/RJ_qV175ADL4dyq4-yi96--74O_qwQKAh4MeTlG3O-LmjYpT379abI6AGLhfqfO0Mu2I9p9JoMBBOa7BOw=w120-h120-l90-rj"
#             },
#             {
#                 "id": "Kmm8qDtnHEo",
#                 "name": "Taylor Swift - Haunted",
#                 "title": "Haunted",
#                 "artists": [
#                     {
#                         "artist_id": "UCPC0L1d253x-KuMNwa05TpA",
#                         "name": "Taylor Swift"
#                     }
#                 ],
#                 "album": {
#                     "album_id": "MPREb_X9EjrualqFN",
#                     "name": "Speak Now"
#                 },
#                 "duration": 242,
#                 "thumbnail": "https://lh3.googleusercontent.com/PNZlZc5kNUgLhpXn5vNkVl8wEsFHg26uEbNMRLRcTioJ8qnAEqV3EOjLwEh7YYeRmNul6TLXEv1v1fk=w120-h120-l90-rj"
#             }
#         ],
#         "videos": [
#             {
#                 "id": "b1kbLwvqugk",
#                 "title": "Anti-Hero",
#                 "duration": 310
#             },
#             {
#                 "id": "b7QlX3yR2xs",
#                 "title": "Bejeweled",
#                 "duration": 354
#             },
#             {
#                 "id": "e-ORhEE9VVg",
#                 "title": "Blank Space",
#                 "duration": 273
#             },
#             {
#                 "id": "VuNIsY6JdUw",
#                 "title": "You Belong With Me Closed-Captioned",
#                 "duration": 229
#             },
#             {
#                 "id": "nfWlot6h_JM",
#                 "title": "Shake It Off",
#                 "duration": 242
#             },
#             {
#                 "id": "3tmd-ClpJxA",
#                 "title": "Look What You Made Me Do",
#                 "duration": 256
#             },
#             {
#                 "id": "5UMCrq-bBCg",
#                 "title": "Taylor Swift ft. Chris Stapleton - I Bet You Think About Me (...",
#                 "duration": 376
#             },
#             {
#                 "id": "Dkk9gvTmCXY",
#                 "title": "You Need To Calm Down",
#                 "duration": 211
#             },
#             {
#                 "id": "QcIy9NiNbmo",
#                 "title": "Bad Blood (feat. Kendrick Lamar)",
#                 "duration": 245
#             },
#             {
#                 "id": "WA4iX5D9Z64",
#                 "title": "We Are Never Ever Getting Back Together",
#                 "duration": 216
#             },
#             {
#                 "id": "AgFeZr5ptV8",
#                 "title": "22",
#                 "duration": 243
#             },
#             {
#                 "id": "-BjZmE2gtdo",
#                 "title": "Lover",
#                 "duration": 239
#             },
#             {
#                 "id": "IdneKLhsWOQ",
#                 "title": "Wildest Dreams",
#                 "duration": 235
#             },
#             {
#                 "id": "8xg3vE8Ie_E",
#                 "title": "Love Story Closed-Captioned",
#                 "duration": 237
#             },
#             {
#                 "id": "wIft-t-MQuE",
#                 "title": "...Ready For It?",
#                 "duration": 211
#             }
#         ]
#     }
# }
