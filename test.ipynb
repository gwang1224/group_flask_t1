# %%
import requests
import json # using .json to reorganize raw data

favorites = {}
fav_artist_list = []

def initmusicAPI(artist): 
    """Given input of artist name, returns dictionary of api"""

    url = "https://youtube-music1.p.rapidapi.com/v2/search"
    querystring = {"query":artist}
    headers = {
	    "X-RapidAPI-Key": "4a1e45ca8dmshcde31ef8a5baed3p1a2a7ejsn9952d2cf96bd", # use personal key
	    "X-RapidAPI-Host": "youtube-music1.p.rapidapi.com"
    }
    response = requests.request("GET", url, headers=headers, params=querystring)

    dict = json.loads(response.text)
    return dict

def album(artist):
    """input artist name, returns list of all artist's albums"""

    api_dictionary = extract_api_data(artist)
    album_list = [] # create a new list to start from scratch
    songlist = api_dictionary["result"]["songs"] # dictionary values from API dictionary

    for song in songlist:
        if song["album"]["name"] not in album_list: 
            album_list.append(song["album"]["name"])
    return album_list


def song(artist, album):
    """Given input of artist name and album 
    name, returns songs in album if query is
    found, if not, returns Information not found"""

    song_list = []
    api_dictionary = extract_api_data(artist)
    song_data = api_dictionary["result"]["songs"]

    found = False # by default nothing is found

    for song in song_data:
        if song["album"]["name"] == album: # if machine is able to find song name in dictionary then song names will be printed
            song_list.append(song["name"])
            #print(song["name"])
            found = True # variable is now set as true

    if found == False: 
        print("Information not found")
    return song_list

def fav_artist(artist):
    """Creates dictionary with artist key and number of likes in value"""
    fav_artist_list.append(artist)

    for artist in fav_artist_list:
        favorites[artist] = fav_artist_list.count(artist)
    
    return favorites

def favorites_ranked(dictionary):
    sorted_dict = dict(sorted(dictionary.items(), key=lambda x:x[1]))
    return sorted_dict

# %%
# Example
artist_input = ""
album_input = "1989"

# %%
print(album(artist_input))
# Out:
# ['Allowing Flow', 'A Question Like This Can Really Open Eyebrows', 'Vegecide', 'Vegecide (7.0 Edition)', 'asdfasdf']

# %%
print(song(artist_input, album_input))
# Out:
# ['Taylor Swift - Style']

# %%
input_artist = "Harry Styles"
fav_artist(input_artist)
# Out:
# {'Harry Styles': 9, 'Taylor Swift': 5, 'Conan Gray': 7}

# %%
print(favorites)
# Out:
# {'Harry Styles': 9, 'Taylor Swift': 5, 'Conan Gray': 7}

# %%
ranked = favorites_ranked(favorites)
print(ranked)
# Out:
# {'Taylor Swift': 5, 'Conan Gray': 7, 'Harry Styles': 9}

# %%
artist = "Taylor Swift" # allow user to input the artist they want

url = "https://youtube-music1.p.rapidapi.com/v2/search"

querystring = {"query":artist}

headers = {
    "X-RapidAPI-Key": "4a1e45ca8dmshcde31ef8a5baed3p1a2a7ejsn9952d2cf96bd", # use personal key
    "X-RapidAPI-Host": "youtube-music1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)
string_val = response.text
dict_val = json.loads(string_val)

formated = json.dumps(dict_val, indent=4)
print(formated)
# Out:
# {
#     "ok": true,
#     "result": {
#         "songs": [
#             {
#                 "id": "gGwN25z7FrE",
#                 "name": "Taylor Swift - Anti-Hero",
#                 "title": "Anti-Hero",
#                 "artists": [
#                     {
#                         "artist_id": "UCPC0L1d253x-KuMNwa05TpA",
#                         "name": "Taylor Swift"
#                     }
#                 ],
#                 "album": {
#                     "album_id": "MPREb_z0ABWl3jaT0",
#                     "name": "Midnights"
#                 },
#                 "duration": 201,
#                 "thumbnail": "https://lh3.googleusercontent.com/omCs21jqwK4Ss_VZxPFKwQP5z0UY0vi_8gXu4XNxHKDgE-GHYHWkIw80XR1uzFgdyhM3PvVUZeZ8iAfF=w120-h120-l90-rj"
#             },
#             {
#                 "id": "3YgtjHZyCIQ",
#                 "name": "Taylor Swift - Anti-Hero",
#                 "title": "Anti-Hero",
#                 "artists": [
#                     {
#                         "artist_id": "UCPC0L1d253x-KuMNwa05TpA",
#                         "name": "Taylor Swift"
#                     }
#                 ],
#                 "album": {
#                     "album_id": "MPREb_MOJF3UvLsif",
#                     "name": "Midnights (3am Edition)"
#                 },
#                 "duration": 201,
#                 "thumbnail": "https://lh3.googleusercontent.com/YT8q7RwmbNVf7EcjSii-T5vm7FZI7_mSb_KYvhfKqvKRWdCTB-mzr2jLZCPwYqER3wHFXhuEQKTKmUCJ=w120-h120-l90-rj"
#             },
#             {
#                 "id": "ywUqTGWU7ec",
#                 "name": "Taylor Swift - Bejeweled",
#                 "title": "Bejeweled",
#                 "artists": [
#                     {
#                         "artist_id": "UCPC0L1d253x-KuMNwa05TpA",
#                         "name": "Taylor Swift"
#                     }
#                 ],
#                 "album": {
#                     "album_id": "MPREb_z0ABWl3jaT0",
#                     "name": "Midnights"
#                 },
#                 "duration": 195,
#                 "thumbnail": "https://lh3.googleusercontent.com/omCs21jqwK4Ss_VZxPFKwQP5z0UY0vi_8gXu4XNxHKDgE-GHYHWkIw80XR1uzFgdyhM3PvVUZeZ8iAfF=w120-h120-l90-rj"
#             },
#             {
#                 "id": "bhnaPBK9nOQ",
#                 "name": "Taylor Swift - Wildest Dreams (Taylor's Version)",
#                 "title": "Wildest Dreams (Taylor's Version)",
#                 "artists": [
#                     {
#                         "artist_id": "UCPC0L1d253x-KuMNwa05TpA",
#                         "name": "Taylor Swift"
#                     }
#                 ],
#                 "album": {
#                     "album_id": "MPREb_01wk3vyacN8",
#                     "name": "This Love (Taylor\u2019s Version)"
#                 },
#                 "duration": 221,
#                 "thumbnail": "https://lh3.googleusercontent.com/84HwoAMSxh8WaUR7iCc4TiXIyfGsbaiiipxDHDl3hnnpialoNXBkv15jtI6VB6smxMOR5Qs0MyW2Ojs=w120-h120-l90-rj"
#             },
#             {
#                 "id": "Gh7u-KTWUq8",
#                 "name": "Taylor Swift - Speak Now",
#                 "title": "Speak Now",
#                 "artists": [
#                     {
#                         "artist_id": "UCPC0L1d253x-KuMNwa05TpA",
#                         "name": "Taylor Swift"
#                     }
#                 ],
#                 "album": {
#                     "album_id": "MPREb_X9EjrualqFN",
#                     "name": "Speak Now"
#                 },
#                 "duration": 240,
#                 "thumbnail": "https://lh3.googleusercontent.com/PNZlZc5kNUgLhpXn5vNkVl8wEsFHg26uEbNMRLRcTioJ8qnAEqV3EOjLwEh7YYeRmNul6TLXEv1v1fk=w120-h120-l90-rj"
#             },
#             {
#                 "id": "hYt5NSjWKds",
#                 "name": "Taylor Swift - Style",
#                 "title": "Style",
#                 "artists": [
#                     {
#                         "artist_id": "UCPC0L1d253x-KuMNwa05TpA",
#                         "name": "Taylor Swift"
#                     }
#                 ],
#                 "album": {
#                     "album_id": "MPREb_K9GL6DCDUCq",
#                     "name": "1989"
#                 },
#                 "duration": 230,
#                 "thumbnail": "https://lh3.googleusercontent.com/xlHRih4BZH9CMxxYRc7IYy2ssXT8gvA8ItKoByOGKtUuC0QX7ISvLkTNARz3AlaAaSiu5v-fMJCgw2UU=w120-h120-l90-rj"
#             },
#             {
#                 "id": "uLL2xTK35Qc",
#                 "name": "Taylor Swift - Lover",
#                 "title": "Lover",
#                 "artists": [
#                     {
#                         "artist_id": "UCPC0L1d253x-KuMNwa05TpA",
#                         "name": "Taylor Swift"
#                     }
#                 ],
#                 "album": {
#                     "album_id": "MPREb_6oiqzmwuS9F",
#                     "name": "Lover"
#                 },
#                 "duration": 222,
#                 "thumbnail": "https://lh3.googleusercontent.com/OhxDTHQOQzSrcdgH9hzqzp1v22GYDE-QKnkryvCeq4ddx-3K3_c8oDXN0E6NvHlMn1q4XV59aHr0oL4f=w120-h120-l90-rj"
#             },
#             {
#                 "id": "Q363dykHdBI",
#                 "name": "Taylor Swift - Glitch",
#                 "title": "Glitch",
#                 "artists": [
#                     {
#                         "artist_id": "UCPC0L1d253x-KuMNwa05TpA",
#                         "name": "Taylor Swift"
#                     }
#                 ],
#                 "album": {
#                     "album_id": "MPREb_MOJF3UvLsif",
#                     "name": "Midnights (3am Edition)"
#                 },
#                 "duration": 149,
#                 "thumbnail": "https://lh3.googleusercontent.com/YT8q7RwmbNVf7EcjSii-T5vm7FZI7_mSb_KYvhfKqvKRWdCTB-mzr2jLZCPwYqER3wHFXhuEQKTKmUCJ=w120-h120-l90-rj"
#             },
#             {
#                 "id": "FhPLQVlUiNQ",
#                 "name": "Taylor Swift - Getaway Car",
#                 "title": "Getaway Car",
#                 "artists": [
#                     {
#                         "artist_id": "UCPC0L1d253x-KuMNwa05TpA",
#                         "name": "Taylor Swift"
#                     }
#                 ],
#                 "album": {
#                     "album_id": "MPREb_BdDqjcHkOwb",
#                     "name": "reputation"
#                 },
#                 "duration": 233,
#                 "thumbnail": "https://lh3.googleusercontent.com/RuKPkn6LLmXNOUcyRqh0zQbMWTpZDhHnkxHEZHrv6J8AbxLwemm9F0xaPpHX51WB_Xlj00My9vpZ_zRh=w120-h120-l90-rj"
#             },
#             {
#                 "id": "5CbWqM0K2v8",
#                 "name": "Taylor Swift - The Way I Loved You (Taylor\u2019s Version)",
#                 "title": "The Way I Loved You (Taylor\u2019s Version)",
#                 "artists": [
#                     {
#                         "artist_id": "UCPC0L1d253x-KuMNwa05TpA",
#                         "name": "Taylor Swift"
#                     }
#                 ],
#                 "album": {
#                     "album_id": "MPREb_W8Sz9ZLayFV",
#                     "name": "Fearless (Taylor's Version)"
#                 },
#                 "duration": 244,
#                 "thumbnail": "https://lh3.googleusercontent.com/huIYugJjpimikk-tSDJyDU09Jr8vDVJuLOh5uGG6T45c5MEtYvFW_9NlqkHHSaLl231kLBgAS8rtDfQ=w120-h120-l90-rj"
#             },
#             {
#                 "id": "X1ebhLz13Ug",
#                 "name": "Taylor Swift - Last Kiss",
#                 "title": "Last Kiss",
#                 "artists": [
#                     {
#                         "artist_id": "UCPC0L1d253x-KuMNwa05TpA",
#                         "name": "Taylor Swift"
#                     }
#                 ],
#                 "album": {
#                     "album_id": "MPREb_X9EjrualqFN",
#                     "name": "Speak Now"
#                 },
#                 "duration": 367,
#                 "thumbnail": "https://lh3.googleusercontent.com/PNZlZc5kNUgLhpXn5vNkVl8wEsFHg26uEbNMRLRcTioJ8qnAEqV3EOjLwEh7YYeRmNul6TLXEv1v1fk=w120-h120-l90-rj"
#             },
#             {
#                 "id": "QQXZyf0OJpI",
#                 "name": "Taylor Swift - 22",
#                 "title": "22",
#                 "artists": [
#                     {
#                         "artist_id": "UCPC0L1d253x-KuMNwa05TpA",
#                         "name": "Taylor Swift"
#                     }
#                 ],
#                 "album": {
#                     "album_id": "MPREb_6FbAboRIFSX",
#                     "name": "Red"
#                 },
#                 "duration": 233,
#                 "thumbnail": "https://lh3.googleusercontent.com/_HJASc9B_QXn2yoUBn4ZLkn6ka8o_CYX4hNT3HQSeIRcqStiJU15VVtOwlaoFV4KqhJK3d-0W0sw3yQ=w120-h120-l90-rj"
#             },
#             {
#                 "id": "KdJHBYb8S4Y",
#                 "name": "Taylor Swift - Better Than Revenge",
#                 "title": "Better Than Revenge",
#                 "artists": [
#                     {
#                         "artist_id": "UCPC0L1d253x-KuMNwa05TpA",
#                         "name": "Taylor Swift"
#                     }
#                 ],
#                 "album": {
#                     "album_id": "MPREb_X9EjrualqFN",
#                     "name": "Speak Now"
#                 },
#                 "duration": 217,
#                 "thumbnail": "https://lh3.googleusercontent.com/PNZlZc5kNUgLhpXn5vNkVl8wEsFHg26uEbNMRLRcTioJ8qnAEqV3EOjLwEh7YYeRmNul6TLXEv1v1fk=w120-h120-l90-rj"
#             },
#             {
#                 "id": "Kmm8qDtnHEo",
#                 "name": "Taylor Swift - Haunted",
#                 "title": "Haunted",
#                 "artists": [
#                     {
#                         "artist_id": "UCPC0L1d253x-KuMNwa05TpA",
#                         "name": "Taylor Swift"
#                     }
#                 ],
#                 "album": {
#                     "album_id": "MPREb_X9EjrualqFN",
#                     "name": "Speak Now"
#                 },
#                 "duration": 242,
#                 "thumbnail": "https://lh3.googleusercontent.com/PNZlZc5kNUgLhpXn5vNkVl8wEsFHg26uEbNMRLRcTioJ8qnAEqV3EOjLwEh7YYeRmNul6TLXEv1v1fk=w120-h120-l90-rj"
#             },
#             {
#                 "id": "5U7bF68xcRg",
#                 "name": "Taylor Swift - King Of My Heart",
#                 "title": "King Of My Heart",
#                 "artists": [
#                     {
#                         "artist_id": "UCPC0L1d253x-KuMNwa05TpA",
#                         "name": "Taylor Swift"
#                     }
#                 ],
#                 "album": {
#                     "album_id": "MPREb_BdDqjcHkOwb",
#                     "name": "reputation"
#                 },
#                 "duration": 214,
#                 "thumbnail": "https://lh3.googleusercontent.com/RuKPkn6LLmXNOUcyRqh0zQbMWTpZDhHnkxHEZHrv6J8AbxLwemm9F0xaPpHX51WB_Xlj00My9vpZ_zRh=w120-h120-l90-rj"
#             },
#             {
#                 "id": "5l3_WBw9AxE",
#                 "name": "Taylor Swift - Snow On The Beach (feat. Lana Del Rey)",
#                 "title": "Snow On The Beach (feat. Lana Del Rey)",
#                 "artists": [
#                     {
#                         "artist_id": "UCPC0L1d253x-KuMNwa05TpA",
#                         "name": "Taylor Swift"
#                     }
#                 ],
#                 "album": {
#                     "album_id": "MPREb_rrvWqvCOLWO",
#                     "name": "Midnights (3am Edition)"
#                 },
#                 "duration": 257,
#                 "thumbnail": "https://lh3.googleusercontent.com/91_pYScOz_ytFWWesoiEHS6k7_0pmNvNZbV5OyzDkLN00Fxg5wPl4LOf4QuP307fDYUmOGFbFb8ZpUHf=w120-h120-l90-rj"
#             },
#             {
#                 "id": "6Z3QJ4L1Bg0",
#                 "name": "Taylor Swift - This Is Why We Can't Have Nice Things",
#                 "title": "This Is Why We Can't Have Nice Things",
#                 "artists": [
#                     {
#                         "artist_id": "UCPC0L1d253x-KuMNwa05TpA",
#                         "name": "Taylor Swift"
#                     }
#                 ],
#                 "album": {
#                     "album_id": "MPREb_BdDqjcHkOwb",
#                     "name": "reputation"
#                 },
#                 "duration": 207,
#                 "thumbnail": "https://lh3.googleusercontent.com/RuKPkn6LLmXNOUcyRqh0zQbMWTpZDhHnkxHEZHrv6J8AbxLwemm9F0xaPpHX51WB_Xlj00My9vpZ_zRh=w120-h120-l90-rj"
#             },
#             {
#                 "id": "erGyUphZSt8",
#                 "name": "Taylor Swift - Dancing With Our Hands Tied",
#                 "title": "Dancing With Our Hands Tied",
#                 "artists": [
#                     {
#                         "artist_id": "UCPC0L1d253x-KuMNwa05TpA",
#                         "name": "Taylor Swift"
#                     }
#                 ],
#                 "album": {
#                     "album_id": "MPREb_BdDqjcHkOwb",
#                     "name": "reputation"
#                 },
#                 "duration": 211,
#                 "thumbnail": "https://lh3.googleusercontent.com/RuKPkn6LLmXNOUcyRqh0zQbMWTpZDhHnkxHEZHrv6J8AbxLwemm9F0xaPpHX51WB_Xlj00My9vpZ_zRh=w120-h120-l90-rj"
#             },
#             {
#                 "id": "lnjSmqU_OmQ",
#                 "name": "Taylor Swift - I Did Something Bad",
#                 "title": "I Did Something Bad",
#                 "artists": [
#                     {
#                         "artist_id": "UCPC0L1d253x-KuMNwa05TpA",
#                         "name": "Taylor Swift"
#                     }
#                 ],
#                 "album": {
#                     "album_id": "MPREb_WKAJORp9ECS",
#                     "name": "reputation (Big Machine Radio Release Special)"
#                 },
#                 "duration": 239,
#                 "thumbnail": "https://lh3.googleusercontent.com/fx6kz_AXXbWVglzvmChcvFRTwV_nFmSAjuyYUO2XTqO_Es9hv4Fe6scz1pTfNWw6hSWob6gtpsft3vZm=w120-h120-l90-rj"
#             },
#             {
#                 "id": "Nm08yUg38tE",
#                 "name": "Taylor Swift - exile (feat. Bon Iver)",
#                 "title": "exile (feat. Bon Iver)",
#                 "artists": [
#                     {
#                         "artist_id": "UCPC0L1d253x-KuMNwa05TpA",
#                         "name": "Taylor Swift"
#                     }
#                 ],
#                 "album": {
#                     "album_id": "MPREb_VLEl8SjepHO",
#                     "name": "folklore"
#                 },
#                 "duration": 286,
#                 "thumbnail": "https://lh3.googleusercontent.com/q7JVahTldHxztLXfCJfgjf5DHr9mi18m2HKpS_IJqBqvvzfAJKPCh_rg-9v-aoGqp-Cc6PHW3ceFMlIQ=w120-h120-l90-rj"
#             }
#         ],
#         "videos": [
#             {
#                 "id": "b1kbLwvqugk",
#                 "title": "Anti-Hero",
#                 "duration": 310
#             },
#             {
#                 "id": "b7QlX3yR2xs",
#                 "title": "Bejeweled",
#                 "duration": 354
#             },
#             {
#                 "id": "VuNIsY6JdUw",
#                 "title": "You Belong With Me Closed-Captioned",
#                 "duration": 229
#             },
#             {
#                 "id": "Dkk9gvTmCXY",
#                 "title": "You Need To Calm Down",
#                 "duration": 211
#             },
#             {
#                 "id": "5UMCrq-bBCg",
#                 "title": "Taylor Swift ft. Chris Stapleton - I Bet You Think About Me (...",
#                 "duration": 376
#             },
#             {
#                 "id": "nfWlot6h_JM",
#                 "title": "Shake It Off",
#                 "duration": 242
#             },
#             {
#                 "id": "e-ORhEE9VVg",
#                 "title": "Blank Space",
#                 "duration": 273
#             },
#             {
#                 "id": "3tmd-ClpJxA",
#                 "title": "Look What You Made Me Do",
#                 "duration": 256
#             },
#             {
#                 "id": "9eakEQSBR8o",
#                 "title": "Taylor Swift - I Knew You Were Trouble (Lyrics)",
#                 "duration": 224
#             },
#             {
#                 "id": "dfnCAmr569k",
#                 "title": "End Game (feat. Ed Sheeran & Future)",
#                 "duration": 252
#             },
#             {
#                 "id": "egxyRSb_XtI",
#                 "title": "Carolina (From The Motion Picture \u201cWhere The Crawdads Sing\u201d /...",
#                 "duration": 174
#             },
#             {
#                 "id": "xKCek6_dB0M",
#                 "title": "Teardrops On My Guitar",
#                 "duration": 218
#             },
#             {
#                 "id": "KgU7URwpIFI",
#                 "title": "Taylor Swift - Blank Space (Lyrics)",
#                 "duration": 233
#             },
#             {
#                 "id": "-BjZmE2gtdo",
#                 "title": "Lover",
#                 "duration": 239
#             },
#             {
#                 "id": "JLf9q36UsBk",
#                 "title": "Out of the Woods",
#                 "duration": 257
#             },
#             {
#                 "id": "nkmNsAyqi1I",
#                 "title": "Taylor Swift - Wildest Dreams (Lyrics)",
#                 "duration": 219
#             },
#             {
#                 "id": null,
#                 "title": "Taylor Swift - Love Story ( Lyrics )",
#                 "duration": 271
#             }
#         ]
#     }
# }
